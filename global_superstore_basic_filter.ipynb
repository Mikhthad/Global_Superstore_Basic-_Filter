# %% [markdown]
# <a href="https://colab.research.google.com/github/Mikhthad/Global_Superstore_Basic-_Filter/blob/main/global_superstore_basic_filter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/global_superstore.xlsx')

# %%
df
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
df.head(5)
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %%
df.tail(5)
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
#         Customer ID       Customer Name      Segment  Postal Code  \
# 51285    KE-1642066     Katrina Edelman    Corporate          NaN
# 51286  ZD-219251408  Zuschuss Donatelli     Consumer      37421.0
# 51287  ZD-219251404  Zuschuss Donatelli     Consumer      94109.0
# 51288    RB-1979518          Ross Baird  Home Office          NaN
# 51289    MC-1810093       Mick Crebagga     Consumer          NaN
#
#                 City  ...   Product ID         Category Sub-Category  \
# ...

# %%
df.size
# Out:
# 1230960

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   Postal Code     9994 non-null   float64
#  9   City            51290 non-null  object
#  10  State           51290 non-null  object
#  11  Country         51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Market          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Postal Code              float64
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
df.shape
# Out:
# (51290, 24)

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  51290.00000                          51290
# mean   25645.50000  2014-05-11 21:26:49.155780608
# min        1.00000            2012-01-01 00:00:00
# 25%    12823.25000            2013-06-19 00:00:00
# 50%    25645.50000            2014-07-08 00:00:00
# 75%    38467.75000            2015-05-22 00:00:00
# max    51290.00000            2015-12-31 00:00:00
# std    14806.29199                            NaN
#
#                            Ship Date   Postal Code         Sales  \
# count                          51290   9994.000000  51290.000000
# mean   2014-05-15 20:42:42.745174528  55190.379428    246.490581
# min              2012-01-03 00:00:00   1040.000000      0.444000
# 25%              2013-06-23 00:00:00  23223.000000     30.758625
# 50%              2014-07-12 00:00:00  56430.500000     85.053000
# 75%              2015-05-26 00:00:00  90008.000000    251.053200
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# Postal Code       41296
# City                  0
# State                 0
# Country               0
# Region                0
# Market                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Length: 51290, dtype: bool

# %%
df.duplicated(subset=['Customer ID','Product ID']).sum()
# Out:
# 118

# %%
df.duplicated(subset=['Customer ID','City']).sum()
# Out:
# 26337

# %%
df1=df[df.duplicated(subset=['Customer ID','City'])]

# %%
df1
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 8       40099  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 10      36259  CA-2012-AB10015140-40974 2012-03-06 2012-03-07     First Class
# 21      36260  CA-2012-AB10015140-40974 2012-03-06 2012-03-07     First Class
# 34      40976  CA-2013-AH10030140-41635 2013-12-27 2013-12-31  Standard Class
# 50      37425  US-2012-AH10030140-41206 2012-10-24 2012-10-27     First Class
# ...       ...                       ...        ...        ...             ...
# 51280   35112  CA-2014-ZD21925140-41829 2014-07-09 2014-07-09        Same Day
# 51284    9922   MX-2013-KM1637593-41636 2013-12-28 2013-12-31     First Class
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
#
# ...

# %%
#df.drop_duplicates(keep='first',inplace=True)

# %%
df.nunique()
# Out:
# Row ID            51290
# Order ID          25728
# Order Date         1430
# Ship Date          1464
# Ship Mode             4
# Customer ID       17415
# Customer Name       796
# Segment               3
# Postal Code         631
# City               3650
# State              1102
# Country             165
# Region               23
# Market                5
# Product ID         3788
# Category              3
# Sub-Category         17
# Product Name       3788
# Sales             27200
# Quantity             14
# Discount             29
# Profit            28234
# Shipping Cost     16753
# Order Priority        4
# dtype: int64

# %%
df.describe(include='all').T
# Out:
#                   count unique                       top   freq  \
# Row ID          51290.0    NaN                       NaN    NaN
# Order ID          51290  25728  CA-2015-SV20365140-42268     14
# Order Date        51290    NaN                       NaN    NaN
# Ship Date         51290    NaN                       NaN    NaN
# Ship Mode         51290      4            Standard Class  30775
# Customer ID       51290  17415              SV-203651406     26
# Customer Name     51290    796           Muhammed Yedwab    108
# Segment           51290      3                  Consumer  26518
# Postal Code      9994.0    NaN                       NaN    NaN
# City              51290   3650             New York City    915
# State             51290   1102                California   2001
# Country           51290    165             United States   9994
# Region            51290     23            Western Europe   5883
# Market            51290      5              Asia Pacific  14302
# ...

# %%
data_6= { 'Name': ['Alice', 'Bob', 'Charlie', 'Alice', 'Eve', 'Alice'],
        'Age': [24, 27, 22, 24, 29, 24],
      'City': ['New York', 'Los Angeles', 'Chicago', 'New York', 'Chicago', 'New York'] }

# %%
data = pd.DataFrame(data_6)

# %%
data
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 3    Alice   24     New York
# 4      Eve   29      Chicago
# 5    Alice   24     New York

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
data.drop_duplicates(keep='first',inplace=True)

# %%
data
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 4      Eve   29      Chicago

# %%
data_1=data.drop_duplicates(keep='last')

# %%
data_1
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 4      Eve   29      Chicago

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Postal Code              float64
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
df['Postal Code']=df['Postal Code'].astype(str)

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Postal Code               object
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
df
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %% [markdown]
# **Feature**

# %%
df[['Sales','Quantity']]
# Out:
#           Sales  Quantity
# 0       221.980         2
# 1      3709.395         9
# 2      5175.171         9
# 3      2892.510         5
# 4      2832.960         8
# ...         ...       ...
# 51285    65.100         5
# 51286    16.720         5
# 51287     8.560         2
# 51288    13.440         2
# 51289    61.380         3
#
# [51290 rows x 2 columns]

# %%
df['Total_Order_Value'] = df['Sales']*df['Quantity']

# %%
df
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
df['Profit_Margin']=(df['Profit'] / df['Total_Order_Value'])*100

# %%
df
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
#df.drop('Total_Profit_Margin',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-7f53595ea30e> in <cell line: 1>()
# ----> 1 df.drop('Total_Profit_Margin',axis=1,inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5342                 weight  1.0     0.8
#    5343         """
# -> 5344         return super().drop(
#    5345             labels=labels,
#    5346             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709         for axis, labels in axes.items():
#    4710             if labels is not None:
# -> 4711                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4712
#    4713         if inplace:
#
# ...

# %%
df
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
df
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
# create a future that represent the shipping cost per unit sold
df['Shipping_Cost_Per_unit']=df['Shipping Cost']/df['Quantity']

# %%
df
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %% [markdown]
# # order date extract

# %%
df['Order_Year']=df['Order Date'].dt.year

# %%
df
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
df['Order_month'] = df['Order Date'].dt.month

# %%
df['Order_Month_Name'] = df['Order Date'].dt.month_name()

# %%
df.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ... Discount    Profit Shipping Cost Order Priority Total_Order_Value  \
# ...

# %%
df['Order_day'] = df['Order Date'].dt.day
df['Order_day_Name'] = df['Order Date'].dt.day_name()
df.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ... Shipping Cost Order Priority Total_Order_Value Profit_Margin  \
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5cc0934cc03c> in <cell line: 1>()
# ----> 1 df.dtypes
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Ship date extract

# %%
df['Shipping_Year'] = df['Ship Date'].dt.year
df['Shipping_Month'] = df['Ship Date'].dt.month
df['Shipiing_Month_Name'] = df['Ship Date'].dt.month_name()
df['Shipping_day']=df['Ship Date'].dt.day
df['Shipping_Day_Name']=df['Ship Date'].dt.day_name()

# %%
df.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ... Order_Year Order_month Order_Month_Name Order_day Order_day_Name  \
# ...

# %%
df['Delivery_time']=(df['Ship Date']-df['Order Date']).dt.days
df.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ... Order_month Order_Month_Name Order_day Order_day_Name Shipping_Year  \
# ...

# %% [markdown]
# # Display Crunt Date

# %%
import datetime
current_date=datetime.datetime.now()

# %%
df['Order_Age']=(current_date-df['Order Date']).dt.days
df.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer     73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate         nan     Wollongong
# 2     CR-127307      Craig Reiter     Consumer         nan       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         nan         Berlin
# 4    RH-9495111       Rick Hansen     Consumer         nan          Dakar
#
#    ... Order_Month_Name Order_day Order_day_Name Shipping_Year Shipping_Month  \
# ...

# %% [markdown]
# #Replace

# %%
df['Profit'][df['Profit']<0]
# Out:
# 1       -288.7650
# 3        -96.5400
# 16        -2.5248
# 30      -148.4600
# 40       -77.2038
#            ...
# 51260     -1.1100
# 51266    -18.8280
# 51275    -21.1680
# 51277    -49.5720
# 51279     -6.4560
# Name: Profit, Length: 12544, dtype: float64

# %%
#filter rows where the profit negetive and quantity is grater than 10
Filter_Rows=df[(df['Profit']<0) & (df['Quantity']>10)]

# %%
#calculate the avg sales these filter rows
Filter_Rows['Sales'].mean()
# Out:
# 650.2714193333333

# %%
df['Profit']
# Out:
# 0         62.1544
# 1       -288.7650
# 2        919.9710
# 3        -96.5400
# 4        311.5200
#            ...
# 51285      4.5000
# 51286      3.3440
# 51287      2.4824
# 51288      2.4000
# 51289      1.8000
# Name: Profit, Length: 51290, dtype: float64

# %%
df.loc[df['Profit']<0, 'Order_priority']='Urgent'

# %%
df
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority', 'Total_Order_Value',
#        'Profit_Margin', 'Shipping_Cost_Per_unit', 'Order_Year', 'Order_month',
#        'Order_Month_Name', 'Order_day', 'Order_day_Name', 'Shipping_Year',
#        'Shipping_Month', 'Shipiing_Month_Name', 'Shipping_day',
#        'Shipping_Day_Name', 'Delivery_time', 'Order_Age', 'Order_Piority',
#        'Order_priority'],
#       dtype='object')

# %%
#filter where gatogery is furniture and profit greater than 100
df[(df['Category']=='Furniture') & (df['Profit']>100)]
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 6       30570   IN-2012-TS2134092-41219 2012-11-06 2012-11-08     First Class
# 7       31192   IN-2013-MB1808592-41378 2013-04-14 2013-04-18  Standard Class
# 11      28879    ID-2013-AJ107801-41383 2013-04-19 2013-04-22     First Class
# 13       4132   MX-2013-VF2171518-41591 2013-11-13 2013-11-13        Same Day
# 20      46630    PL-2013-AB600103-41494 2013-08-08 2013-08-10     First Class
# ...       ...                       ...        ...        ...             ...
# 50553   39188  CA-2014-TS21655140-41999 2014-12-26 2014-12-30  Standard Class
# 50600   33593  CA-2013-VD21670140-41579 2013-11-01 2013-11-05  Standard Class
# 50917   38354  CA-2014-WB21850140-41985 2014-12-12 2014-12-12        Same Day
# 51192   32107  CA-2012-ZC21910140-41194 2012-10-12 2012-10-14     First Class
# 51193   36485  CA-2013-ZC21910140-41530 2013-09-13 2013-09-18  Standard Class
#
# ...

# %%
df[df['Product Name'].str.contains('Phone')]
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 5       22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01    Second Class
# 12      45794   SA-2012-MM7260110-41269 2012-12-26 2012-12-28    Second Class
# 24       1570   US-2015-NP1832582-42216 2015-07-31 2015-08-01     First Class
# ...       ...                       ...        ...        ...             ...
# 50805   31512  CA-2013-VW21775140-41275 2013-01-01 2013-01-08  Standard Class
# 50858    8089   US-2015-PS1904598-42349 2015-12-11 2015-12-16  Standard Class
# 50881   43296   PL-2012-DB2910103-41005 2012-04-06 2012-04-08    Second Class
# 51200   32343  CA-2014-ZC21910140-41707 2014-03-09 2014-03-14  Standard Class
# 51262   31316  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
#
# ...

# %%
df.drop(columns='Order_Piority',axis=1,inplace=True)

# %%
# how many rows have 'urgent' as the order priority
df[df['Order_priority']=='Urgent'].shape[0]
# Out:
# 12544

# %%
len(df[df['Order_priority']=='Urgent'])
# Out:
# 12544

# %% [markdown]
# # Sorting

# %%
df[['Product Name',"Sales"]].sort_values(by='Sales',ascending=False)
# Out:
#                                             Product Name      Sales
# 47114  Cisco TelePresence System EX90 Videoconferenci...  22638.480
# 49003              Canon imageCLASS 2200 Advanced Copier  17499.950
# 44248              Canon imageCLASS 2200 Advanced Copier  13999.960
# 49940              Canon imageCLASS 2200 Advanced Copier  11199.968
# 25238              Canon imageCLASS 2200 Advanced Copier  10499.970
# ...                                                  ...        ...
# 24977                                  Acco 3-Hole Punch      0.876
# 26588                      Avery Round Ring Poly Binders      0.852
# 33493  Avery Durable Slant Ring Binders With Label Ho...      0.836
# 45391           Acco Suede Grain Vinyl Round Ring Binder      0.556
# 51260  Hoover Replacement Belt for Commercial Guardsm...      0.444
#
# [51290 rows x 2 columns]

# %%
#sort the data set first by category in ascending order and then by profit in descenting order
df[['Category','Profit']].sort_values(by=['Category','Profit'],ascending=[True,False])
# Out:
#          Category     Profit
# 334     Furniture  2316.5100
# 42      Furniture  2097.0300
# 192     Furniture  2071.4400
# 118     Furniture  1868.1300
# 940     Furniture  1622.8800
# ...           ...        ...
# 362    Technology -3009.4350
# 47527  Technology -3399.9800
# 23110  Technology -3839.9904
# 6591   Technology -4088.3760
# 11755  Technology -6599.9780
#
# [51290 rows x 2 columns]

# %%
#how can  you sort the dataset by quantity in descending order and then select the top 10 records
df.sort_values(by=['Quantity'],ascending=False).head(10)
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 7971    43213    CG-2015-JR570033-42272 2015-09-25 2015-09-30  Standard Class
# 17405   19420  IT-2015-MG18205139-42242 2015-08-26 2015-08-29    Second Class
# 40522   34244  CA-2015-MP18175140-42353 2015-12-15 2015-12-19  Standard Class
# 15388   26869    IN-2012-MW182357-41052 2012-05-23 2012-05-27  Standard Class
# 33134   43138    NI-2014-PR888095-41982 2014-12-09 2014-12-11     First Class
# 13398   32726  US-2013-DK12835140-41578 2013-10-31 2013-11-04    Second Class
# 17675   47093     AU-2015-DA34508-42355 2015-12-17 2015-12-22  Standard Class
# 10107   19306  ES-2013-SC20260139-41625 2013-12-17 2013-12-21    Second Class
# 2680    49660  TU-2013-TA11385134-41326 2013-02-21 2013-02-27  Standard Class
# 31397   49851   PL-2015-BD1725103-42217 2015-08-01 2015-08-08  Standard Class
#
#         Customer ID     Customer Name      Segment Postal Code           City  \
# ...

# %%
data = { 'Timestamp': ['2024-07-24 14:45:00', '2024-07-25 16:30:00',
                                         '2024-07-26 08:20:00', '2024-07-27 12:15:00'] }
df11 = pd.DataFrame(data)

# %%
df11
# Out:
#              Timestamp
# 0  2024-07-24 14:45:00
# 1  2024-07-25 16:30:00
# 2  2024-07-26 08:20:00
# 3  2024-07-27 12:15:00

# %%
df11.dtypes
# Out:
# Timestamp    object
# dtype: object

# %%
df11['Timestamp']=df11['Timestamp'].astype('datetime64[ns]')

# %%
df11['Timestamp']=pd.to_datetime(df['Timestamp'])

# %%
df11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  4 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 160.0 bytes

# %%
df11['Order_Day'] = df11['Timestamp'].dt.day
df11['Order_Day_Name'] = df11['Timestamp'].dt.day_name()
df11['Year'] = df11['Timestamp'].df.year
df11 ['Minute'] = df11['Timestamp'].df.Minute
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-f4dde4cc820e> in <cell line: 3>()
#       1 df11['Order_Day'] = df11['Timestamp'].dt.day
#       2 df11['Order_Day_Name'] = df11['Timestamp'].dt.day_name()
# ----> 3 df11['Year'] = df11['Timestamp'].df.year
#       4 df11 ['Minute'] = df11['Timestamp'].df.Minute
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# AttributeError: 'Series' object has no attribute 'df'

# %%
df11
# Out:
#             Timestamp  Order_Day Order_Day_Name  Month
# 0 2024-07-24 14:45:00         24      Wednesday      7
# 1 2024-07-25 16:30:00         25       Thursday      7
# 2 2024-07-26 08:20:00         26         Friday      7
# 3 2024-07-27 12:15:00         27       Saturday      7
